# %% [markdown]
# ![](https://www.dii.uchile.cl/wp-content/uploads/2021/06/Magi%CC%81ster-en-Ciencia-de-Datos.png)

# %% [markdown]
# # **Proyecto 1 - MDS7202 Laboratorio de Programación Científica para Ciencia de Datos 📚**
#
# **MDS7202: Laboratorio de Programación Científica para Ciencia de Datos**
#
# ### Cuerpo Docente:
#
# - Profesor: Ignacio Meza, Gabriel Iturra
# - Auxiliar: Sebastián Tinoco
# - Ayudante: Arturo Lazcano, Angelo Muñoz
#
# *Por favor, lean detalladamente las instrucciones de la tarea antes de empezar a escribir.*
#
# ### Equipo:
#
# - \<Diego Kauer\>
# - \<Vicente Correa\>
#
#
# ### Link de repositorio de GitHub: `\<https://github.com/diegokauer/MDS7202\>`
#
# Fecha límite de entrega 📆: 27 de Octubre de 2023.

# %% [markdown]
# ----
#
# ## Reglas
#
# - **Grupos de 2 personas.**
# - Cualquier duda fuera del horario de clases al foro. Mensajes al equipo docente serán respondidos por este medio.
# - Estrictamente prohibida la copia.
# - Pueden usar cualquier material del curso que estimen conveniente.

# %% [markdown]
# <div style="text-align: center;">
#     <img src="https://worldskateamerica.org/wp-content/uploads/2023/07/SANTIAGO-2023-1-768x153.jpg" alt="Descripción de la imagen">
# </div>
#
# En un Chile azotado por un profundo caos político-económico y el resurgimiento de programas de televisión de dudosa calidad, todas las miradas y esperanzas son depositadas en el éxito de un único evento: Santiago 2023. La nación necesitaba desesperadamente un respiro, y los Juegos de Santiago 2023 prometían ser una luz al final del túnel.
#
# El Presidente de la República -conocido en las calles como Bombín-, consciente de la importancia de este evento para la revitalización del país, decide convocar a usted y su equipo en calidad de expertos en análisis de datos y estadísticas. Con gran solemnidad, el presidente les encomienda una importante y peligrosa: liderar un proyecto que permitiera caracterizar de forma automática y eficiente los datos generados por estos magnos juegos. Para esto, el presidente le destaca que la solución debe considerar los siguientes puntos:
# - Caracterización automática de los datos
# - La solución debe ser compatible con cualquier dataset
# - Se les facilita el dataset *olimpiadas.parquet*, el cual recopila data de diferentes juegos olímpicos realizados en los últimos años

# %% [markdown]
# ## 1.1 Creación de `Profiler` Class (4.0 puntos)
#
# Cree la clase `Profiler`. Como mínimo, esta debe tener las siguientes funcionalidades:
#
# 1. El método constructor, el cual debe recibir los datos a procesar en formato `Pandas DataFrame`. Además, este método debe generar una carpeta en su directorio de trabajo con el nombre `EDA_fecha`, donde `fecha` corresponda a la fecha de ejecución en formato `DD-MM-YYYY`.
#
# 2. El método `summarize`, el cual debe caracterizar las variables del Dataset. Como mínimo, se espera que su método pueda:
#     - Implementar una funcionalidad para filtrar y aplicar este método a una o más variables de interés.
#     - Reportar el tipo de variable
#     - Reportar el número y/o porcentaje de valores únicos de la variable
#     - Reportar el número y/o porcentaje de valores nulos
#     - Si la variables es numérica:
#         - Reportar el número y/o porcentaje de valores cero, negativos y outliers
#         - Reportar estadística descriptiva como el valor mínimo, máximo, promedio y los percentiles 25, 50, 75 y 100
#    - Levantar una alerta en caso de encontrar alguna anomalía fuera de lo común (el criterio debe ser ajustable por el usuario)
#    - Guardar sus resultados en el directorio `EDA_fecha/summary.txt`. El archivo debe separar de forma clara y ordenada los resultados de cada punto.
#
# 3. El método `plot_vars`, el cual debe graficar la distribución e interraciones de las variables del Dataset. Como mínimo, se espera que su método pueda:
#     - Crear la carpeta `EDA_fecha/plots`
#     - Implementar una funcionalidad para filtrar y aplicar este método a una o más variables de interés.
#     - Para las variables numéricas:
#         - Genere un gráfico de distribución de densidad
#         - Grafique la correlación entre las variables
#     - Para las variables categóricas:
#         - Genere un histograma de las top N categorías (N debe ser un parámetro ajustable)
#         - Grafique el coeficiente V de Cramer entre las variables
#     - Guardar cada gráfico generado en la carpeta `EDA_fecha/plots` en formato `.pdf` y bajo el naming `variable.pdf`, donde `variable` es el nombre de la variable de interés
#
# 4. El método `clean_data`, el cual debe limpiar los datos para que luego puedan ser procesados. Como mínimo, se espera que su método pueda:
#     - Crear la carpeta `EDA_fecha/clean_data`
#     - Implementar una funcionalidad para filtrar y aplicar este método a una o más variables de interés.
#     - Drop de valores duplicados
#     - Implementar como mínimo 2 técnicas para tratar los valores nulos, como:
#         - Drop de valores nulos
#         - Imputar valores nulos con alguna técnica de imputación
#         - Funcionalidad para escoger entre una técnica y la otra.
#     - Una de las columnas del dataframe presenta datos *no atómicos*. Separe dicha columna en las columnas que la compongan.
#         - Hint: ¿Qué caracteres permiten separar una columna de otra?
#         - Para las pruebas con el dataset nuevo, puede esperar que exista al menos una columna con este tipo de problema. Asuma que los separadores serán los mismos, aunque el número de columnas a separar puede ser distinto.
#     - Deberían usar `FunctionTransformer`.
#     - Guardar los datos procesados en formato `.csv` en el path `EDA_fecha/clean_data/data.csv`
#
# 5. El método `scale`, el cual debe preparar adecuadamente los datos para luego ser consumidos por algún tipo de algoritmo. Como mínimo, se espera que su método pueda:
#     - Crear la carpeta `EDA_fecha/scale`
#     - Procesar de forma adecuada los datos numéricos y categóricos:
#         - Su método debe recibir las técnicas de escalamiento como argumento de entrada (utilizar solo técnicas compatibles con el framework de `sklearn`)
#         - Para los atributos numéricos, se transforme los datos con un escalador logarítmico y un `MinMaxScaler`
#         - Asuma que no existen datos ordinales en su dataset
#     - Guardar todo este procesamiento en un `ColumnTransformer`.
#     - Guardar los datos limpios y transformados en formato `.csv` en el path `EDA_fecha/process/scaled_features.csv`
#
# 6. El método `make_clusters`, el cual debe generar clusters de los datos usando algún algoritmo de clusterización. Como mínimo, se espera que su método pueda:
#     - Crear la carpeta `EDA_fecha/clusters`
#     - Generar un estudio del codo donde señale la cantidad de clusters optimos para el desarrollo.
#     - Su método debe recibir el algoritmo de clustering como argumento de entrada (utilizar solo algoritmos compatibles con el framework de `sklearn`).
#     - No olvide pre procesar adecuadamente los datos antes de implementar la técnica de clustering.
#     - En este punto es espera que generen un `Pipeline` de sklearn. Además, su método debería usar lo construido en los puntos 4 y 5.
#     - Su método debe ser capaz de funcionar a partir de datos crudos (se descontará puntaje de lo contrario).
#     - Una vez generado los clusters, proyecte los datos a 2 dimensiones usando su técnica de reducción de dimensionalidad favorita y grafique los resultados coloreando por cluster.
#     - Guardar los datos con su respectivo cluster en formato `.csv` en el path `EDA_fecha/clusters/data_clusters.csv`. Guarde también los gráficos generados en el mismo path.
#
# 7. El método `detect_anomalies`, el cual debe detectar anomalías en los datos. Como mínimo, se espera que su método pueda:
#
#     - Crear la carpeta `EDA_fecha/anomalies`
#     - Implementar alguna técnica de detección de anomalías.
#     - Al igual que el punto anterior, su método debe considerar los siguientes puntos:
#         - No olvide pre procesar de forma adecuada los datos antes de implementar la técnica de detección de anomalía.
#         - En este punto es espera que generen un `Pipeline` de sklearn. Además, su método debería usar lo construido en los puntos 4 y 5.
#         - Su método debe ser capaz de funcionar a partir de datos crudos (se descontará puntaje de lo contrario).
#         - Su método debe recibir el algoritmo como argumento de entrada
#         - Una vez generado las etiquetas, proyecte los datos a 2 dimensiones y grafique los resultados coloreando por las etiquetas predichas por el detector de anomalías
#     - Guardar los datos con su respectiva etiqueta en formato `.csv` en el path `EDA_fecha/anomalies/data_anomalies.csv`. Guarde también los gráficos generados en el mismo path.
#
# 8. El método `profile`, el cual debe ejecutar todos los métodos anteriores.
#
# 9. Crear el método `clearGarbage` para eliminar las carpetas/archivos creados/as por la clase `Profiler`.
#
# Algunas consideraciones generales:
# - Su clase será testeada con datos tabulares diferentes a los provistos. No desarrollen código *hardcodeado*: su clase debe ser capaz de funcionar para **cualquier** dataset.
# - Aplique todo su conocimiento sobre buenas prácticas de programación: se evaluará que su código sea limpio y ordenado.
# - Recuerden documentar cada una de las funcionalidades que implementen.
# - Recuerden adjuntar sus `requirements.txt` junto a su entrega de proyecto. **El código que no se pueda ejecutar por imcompatibilidades de librerías no será corregido.**

# %%
import os
import datetime
from sklearn.pipeline import Pipeline
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import FunctionTransformer, MinMaxScaler, LabelEncoder, OneHotEncoder
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from sklearn.ensemble import IsolationForest
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re
import warnings
import shutil
warnings.filterwarnings("ignore")

class Profiler():
    def __init__(self, df, scale_method=None, cluster_method=None, anomalies_method=None):
        self.data = df.copy()
        self.scale_method = scale_method
        self.cluster_method = cluster_method
        self.anomalies_method = anomalies_method
        today = datetime.date.today().strftime("%d-%m-%Y")
        dir_name = f'EDA_{today}'
        self.dir_name = dir_name
        if not os.path.exists(dir_name):
            os.makedirs(dir_name)
        self.clean_transformer = None
        self.scaler_transformer = None
    
    def summarize(self, columns=None, custom_threshold=None):
        if columns is None:
            columns = self.data.columns

        summary_results = []
        
        #Contar los duplicados
        duplicados = self.data.duplicated().sum()
        print(f'Número de Datos Duplicados: {duplicados}')
        print(f'% de Datos Duplicados: {(duplicados / len(self.data) * 100):.2f}%')
        print('\n')
        
        for column in columns:
            # Se revisa si las columnas filtradas pertenecen al dataset
            if column not in self.data.columns:
                print(f"Warning: {column} no encontrada en el dataset.")
                continue
            column_data = self.data[column]
            variable_type = str(column_data.dtypes)
            unique_count = column_data.nunique()
            missing_count = column_data.isnull().sum()

            if variable_type == 'object':
                print(f'Variable: {column} (Categorica)')
                print(f'Número de Valores Únicos: {unique_count}')
                print(f'% de Valores Faltantes: {(missing_count / len(column_data) * 100):.2f}%')
                summary_results.append(f'Variable: {column} (Categorica)')
                summary_results.append(f'Número de Valores Únicos: {unique_count}')
                summary_results.append(f'% de Valores Faltantes: {(missing_count / len(column_data) * 100):.2f}%')
            else:
                print(f'Variable: {column} (Categorica)')
                print(f'Número de Valores Únicos: {unique_count}')
                print(f'% de Valores Faltantes: {(missing_count / len(column_data) * 100):.2f}%')
                print(f'Valor Mínimo: {column_data.min()}')
                print(f'Valor Máximo: {column_data.max()}')
                print(f'Promedio: {column_data.mean()}')
                print(f'Percentil 25: {column_data.quantile(0.25)}')
                print(f'Percentil 50 (Mediana): {column_data.median()}')
                print(f'Percentil 75: {column_data.quantile(0.75)}')
                summary_results.append(f'Variable: {column} (Numérica)')
                summary_results.append(f'Número de Valores Únicos: {unique_count}')
                summary_results.append(f'% de Valores Faltantes: {(missing_count / len(column_data) * 100):.2f}%')
                summary_results.append(f'Valor Mínimo: {column_data.min()}')
                summary_results.append(f'Valor Máximo: {column_data.max()}')
                summary_results.append(f'Promedio: {column_data.mean()}')
                summary_results.append(f'Percentil 25: {column_data.quantile(0.25)}')
                summary_results.append(f'Percentil 50 (Mediana): {column_data.median()}')
                summary_results.append(f'Percentil 75: {column_data.quantile(0.75)}')

                # Detección de anomalías en base a un umbral determinado (ajustable)
                if custom_threshold is not None:
                    outliers = sum((column_data - column_data.mean()).abs() > custom_threshold * column_data.std())
                    print(f'N° de outliers: {outliers}')
                    summary_results.append(f'N° de outliers: {outliers}')
            print('\n')
            summary_results.append('\n')

        summary_file = os.path.join(self.dir_name, 'summary.txt')

        with open(summary_file, 'w') as file:
            file.write('\n'.join(summary_results))

        print(f'El resumen está guardado en: {summary_file}')

    def plot_vars(self, columns=None, top_categories=None):
        # Creación de la carpeta EDA_fecha/plots
        plots_dir = os.path.join(self.dir_name, 'plots')
        if 'plots' not in os.listdir(self.dir_name):
            os.makedirs(plots_dir)
        
        if columns is None:
            columns = self.data.columns

        for column in columns:
            # Se revisa si las columnas filtradas pertenecen al dataset
            if column not in self.data.columns:
                print(f"Warning: {column} no encontrada en el dataset.")
                continue

            column_data = self.data[column]
            variable_type = str(column_data.dtypes)

            if variable_type == 'object':
                if top_categories is not None:
                    top_categories_count = column_data.value_counts().head(top_categories)
                    plt.figure(figsize=(10, 6))
                    sns.barplot(x=top_categories_count.index, y=top_categories_count.values)
                    plt.title(f'Top {top_categories} categorías de variable {column}')
                    plt.xticks(rotation=45)
                    plt.show()
                    plt.tight_layout()

                    # Guardar el gráfico en formato PDF
                    plot_file = os.path.join(plots_dir, f'{column}.pdf')
                    plt.savefig(plot_file)
                    plt.show()
                    plt.close()

            else:
                # Gráfico de distribución de densidad
                plt.figure(figsize=(10, 6))
                sns.kdeplot(column_data, shade=True)
                plt.title(f'Gráfico de distribución de densidad de {column}')
                plt.tight_layout()
                plt.show()

                # Guardar el gráfico en formato PDF
                plot_file = os.path.join(plots_dir, f'{column}.pdf')
                plt.savefig(plot_file)
                plt.close()
            
        # Filtrar las columnas numéricas
        numeric_columns = self.data.select_dtypes(include=['number']).columns
        
        # Generar la matriz de correlación para las columnas numéricas
        correlation_matrix = self.data[numeric_columns].corr()
        plt.figure(figsize=(12, 8))
        sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
        plt.title('Matriz de correlación')
        plt.tight_layout()
        plt.show()

        # Guardar la matriz de correlación en formato PDF
        corr_plot_file = os.path.join(plots_dir, 'matriz_correlacion.pdf')
        plt.savefig(corr_plot_file)
        plt.close()
        
        ### Graficar coeficiente V de Cramer
        ###
        ###
        
        print(f'Los gráficos están guardados en: {plots_dir}')

    def clean_data(self, drop_duplicates=True, deal_na=None):
        # Creación de la carpeta EDA_fecha/plots
        clean_dir = os.path.join(self.dir_name, 'clean_data')
        if 'clean_data' not in os.listdir(self.dir_name):
            os.makedirs(clean_dir)
        
        # Definir la función de limpieza
        def cleaning_function(data, drop_duplicates, deal_na):

            if drop_duplicates:
                data = data.drop_duplicates()
            
            # Separar columnas no atómicas
            columna_no_atomica = []
            for columna in data.columns:
                if '-' in columna:
                    columna_no_atomica.append(columna)
                    
            # Define el carácter especial con el que deseas reemplazar los caracteres especiales
            caracter_reemplazo = '-'
                    
            # Separar el nombre de la columna no atómica en las columnas atómicas correspondientes       
            columnas_nuevas = re.split(r'[-_]', columna_no_atomica[0])
            
            # Función para reemplazar caracteres especiales en una cadena
            def reemplazar_caracteres_especiales(cadena):
                # Utiliza una expresión regular para encontrar todos los caracteres especiales excepto los puntos y reemplazarlos
                return re.sub(r'[^A-Za-z0-9.]+', caracter_reemplazo, cadena)
            
            # Aplica la función a la columna no atómica del DataFrame      
            data[columna_no_atomica[0]] = data[columna_no_atomica[0]].apply(reemplazar_caracteres_especiales)
            data[columnas_nuevas] = data[columna_no_atomica[0]].str.split(caracter_reemplazo, expand=True)
                    
            # Función personalizada para tratar 'nan' como NaN al convertir a tipo numérico
            def to_numeric_and_nan(valor):
                if valor.lower() == 'nan':
                    return np.nan
                try:
                    return pd.to_numeric(valor)
                except:
                    return valor  # Mantén el valor si no se puede convertir
                    
            for columna in columnas_nuevas:
                data[columna] = data[columna].apply(to_numeric_and_nan)
                    
            data = data.drop(columna_no_atomica[0], axis=1)
            
            if deal_na == "drop":
                data = data.dropna()
            elif deal_na == "impute":
                for column in data.columns:
                # Revisa si se trata de una columna numérica, para hacer un impute de medias
                    if pd.api.types.is_numeric_dtype(data[column]):
                        # Imputar valores nulos en columnas numéricas con la media
                        data[column].fillna(data[column].mean(), inplace=True)
                    else:
                        # Imputar valores nulos en columnas categóricas con "Unknown"
                        data[column].fillna("Unknown", inplace=True)
            
            return data
        
        # Crear un FunctionTransformer con la función de limpieza
        cleaner = FunctionTransformer(cleaning_function, kw_args={'drop_duplicates': drop_duplicates, 'deal_na': deal_na})

        self.clean_transformer = cleaner
        
        # Aplicar la transformación a los datos
        data = cleaner.fit_transform(self.data)
        
        # Guardar los datos procesados en un archivo CSV
        data_limpia_dir = os.path.join(clean_dir, 'data.csv')
        data.to_csv(data_limpia_dir, index=False)
        
        print(f'La data limpia está en: {data_limpia_dir}')
        
        return data

        
    def scale(self, method):
        # Crear directorio
        dir_name = os.path.join(self.dir_name, 'scale')
        if not os.path.exists(dir_name):
            os.makedirs(dir_name)
            
        self.clean_data(drop_duplicates=True, deal_na='impute')
        scale_df = self.clean_transformer.fit_transform(self.data)

        # Obtener columnas numericas y no-numericas
        num_scale_df = scale_df.select_dtypes(exclude='object')
        obj_scale_df = scale_df.select_dtypes(include='object')

        class CategoricalEncoder(BaseEstimator, TransformerMixin):
            def __init__(self, method):
                self.method = method
                self.encoders = None
                
            def fit(self, X, y=None):
                if isinstance(method, LabelEncoder):
                    encoders = [LabelEncoder().fit(X.loc[:,col]) for col in X.columns]
                    self.encoders = encoders
                    self.columns = X.columns
                else:
                    self.method.fit(X)
                return self

            def transform(self, X, y=None):
                if self.encoders:
                    X = np.stack(tuple(e.transform(X[col]) for e, col in zip(self.encoders, X.columns)), axis=1)
                else:
                    X = self.method.transform(X)
                return X

            def get_feature_names_out(self, a):
                if self.encoders:
                    return self.columns
                return self.method.get_feature_names_out()

        
        # Transformaciones
        def log_minmax(x):
            scaler = MinMaxScaler()
            return scaler.fit_transform(np.log(x + 1))

        scaler = ColumnTransformer(
            [
                ('method', CategoricalEncoder(method), obj_scale_df.columns),
                ('log_minmax', FunctionTransformer(log_minmax, feature_names_out='one-to-one'), num_scale_df.columns),
                # ('minmax', MinMaxScaler(), num_scale_df.columns),
            ], remainder='passthrough'
        )

        # Ajustar datos
        scale_data = scaler.fit_transform(scale_df)
        self.scaler_transformer = scaler

        # Construccion df y guardado
        scale_df = pd.DataFrame(scale_data, columns=scaler.get_feature_names_out())
        scale_df.to_csv(os.path.join(dir_name, 'scaled_features.csv'))

        print(f'La data scaled está en: {os.path.join(dir_name, "scaled_features.csv")}')
        
        return scale_df


    def make_cluster(self, cluster_algo, raw_data=None):
        # Crear directorio
        dir_name = os.path.join(self.dir_name, 'clusters')
        if not os.path.exists(dir_name):
            os.makedirs(dir_name)

        # Obtener datos
        if not raw_data is None:
            self.data = raw_data
            self.scale(self.scale_method)
        else:
            if self.scaler_transformer is None:
                self.scale(self.scale_method)
        data = self.data
        
        # Busqueda de n mediante el metodo del cono
        class CodoKNN(BaseEstimator, TransformerMixin):
            def __init__(self, method):
                self.method = method
                
            def fit(self, X, y=None):
                # Metodo del codo
                inertias = [
                    [i, KMeans(n_clusters=i, random_state=0, n_init='auto').fit(X).inertia_]
                    for i in range(1, 12)]
                inertias = pd.DataFrame(inertias, columns=["n", "inertia"])
                inertias['pct_change'] = inertias['inertia'].pct_change()
                promedios = []
                for i in range(len(inertias)):
                    promedio_fila = inertias.iloc[i:,:]['pct_change'].mean()
                    promedios.append(promedio_fila)
                inertias['promedios'] = promedios
                n = int(inertias.iloc[np.argmax(inertias[inertias.promedios < -0.01].promedios)].n)
                self.method = self.method(n_clusters=n).fit(X)
                return self

            def transform(self, X, y=None):
                X = self.method.transform(X)
                self.labels_ = self.method.labels_
                return X
        

        # Pipe
        pipe = Pipeline([
            ('clean', self.clean_transformer),
            ('scale', self.scaler_transformer),
            ('cluster', CodoKNN(cluster_algo)),
            ('PCA', PCA(n_components=2))
        ], verbose=True)

        # Ajustar datos
        data = pipe.fit_transform(data)

        # Creación de df
        data = pd.DataFrame(data, columns=['pca1', 'pca2'])
        data['cluster'] = pipe['cluster'].labels_

        # Grafico
        fig = sns.scatterplot(data, x='pca1', y='pca2', hue='cluster', palette='tab10').set_title(
            'Clusters de datos'
        )
        plt.show()
        fig = fig.get_figure()
        
        # Guardado csv y imagen
        fig.savefig(os.path.join(dir_name, 'clusters.png'))

        data_cluster = self.clean_data()
        data_cluster['cluster'] = data['cluster']
        data_cluster.to_csv(os.path.join(dir_name, 'data_clusters.csv'))

        print(f'La data de los clusters está en: {os.path.join(dir_name, "data_clusters.csv")}')
        print(f'El grafico está en: {os.path.join(dir_name, "clusters.png")}')
    
    def detect_anomalies(self, detect_anomalies_algo, raw_data=None):
        dir_name = os.path.join(self.dir_name, 'anomalies')
        if not os.path.exists(dir_name):
            os.makedirs(dir_name)

        # Obtener datos
        if not raw_data is None:
            self.data = raw_data
        self.scale(self.scale_method)
        data = self.data

        class DetectAnomalies(BaseEstimator, TransformerMixin):
            def __init__(self, method):
                self.method = method
                
            def fit(self, X, y=None):
                self.method.fit(X)
                return self

            def transform(self, X, y=None):
                self.labels_ = self.method.predict(X)
                return X

        pipe = Pipeline([
            ('clean', self.clean_transformer),
            ('scale', self.scaler_transformer),
            ('anomalies', DetectAnomalies(detect_anomalies_algo())),
            ('PCA', PCA(n_components=2))
        ], verbose=True)


        data = pipe.fit_transform(data)
        
        data = pd.DataFrame(data, columns=['pca1', 'pca2'])
        data['outlier'] = pipe['anomalies'].labels_

        data_an = self.clean_data()
        data_an['outlier'] = data['outlier']
        data_an.to_csv(os.path.join(os.path.join(dir_name, 'data_anomalies.csv')))
        
        fig = sns.scatterplot(data, x='pca1', y='pca2', hue='outlier', palette='tab10').set_title(
            'Detección de anomalias en los datos'
        )
        plt.show()
        fig = fig.get_figure()
        fig.savefig(os.path.join(dir_name, 'anomalies.png'))

        print(f'La data de las anomalias está en: {os.path.join(dir_name, "data_anomalies.csv")}')
        print(f'El grafico está en: {os.path.join(dir_name, "anomalies.png")}')

    def profile(self):
        self.summarize()
        self.plot_vars()
        self.make_cluster(self.cluster_method)
        self.detect_anomalies(self.anomalies_method)

    def clearGarbage(self):
        shutil.rmtree(self.dir_name)

# %%
df = pd.read_parquet('olimpiadas.parquet')
df.head()
# Out:
#    ID                      Name Sex            Team  NOC        Games  Year  \
# 0   1                 A Dijiang   M           China  CHN  1992 Summer  1992
# 1   2                  A Lamusi   M           China  CHN  2012 Summer  2012
# 2   3       Gunnar Nielsen Aaby   M         Denmark  DEN  1920 Summer  1920
# 3   4      Edgar Lindenau Aabye   M  Denmark/Sweden  DEN  1900 Summer  1900
# 4   5  Christine Jacoba Aaftink   F     Netherlands  NED  1988 Winter  1988
#
#    Season       City          Sport                             Event Medal  \
# 0  Summer  Barcelona     Basketball       Basketball Men's Basketball  None
# 1  Summer     London           Judo      Judo Men's Extra-Lightweight  None
# 2  Summer  Antwerpen       Football           Football Men's Football  None
# 3  Summer      Paris     Tug-Of-War       Tug-Of-War Men's Tug-Of-War  Gold
# 4  Winter    Calgary  Speed Skating  Speed Skating Women's 500 metres  None
#
#   age-height-weight
# 0   24.0*180.0?80.0
# ...

# %% [markdown]
# ## 1.2 Caracterizar datos de Olimpiadas (2.0 puntos)
#
# A partir de la clase que hemos desarrollado previamente, procederemos a realizar un análisis exhaustivo de los datos proporcionados en el enunciado. Este análisis se presentará en forma de un informe contenido en el mismo Jupyter Notebook y abordará los siguientes puntos:
#
# 1. Introducción
#     - Se proporcionará una breve descripción del problema que estamos abordando y se explicará la metodología que se seguirá.
#
# Elaborar una breve introducción con todo lo necesario para entender qué realizarán durante su proyecto. La idea es que describan de manera formal el proyecto con sus propias palabras y logren describir algunos aspectos básicos tanto del dataset como del análisis a realizar sobre los datos.
#
# Por lo anterior, en esta sección ustedes deberán ser capaces de:
#
# - Describir la tarea asociada al dataset.
# - Describir brevemente los datos de entrada que les provee el problema.
# - Plantear hipótesis de cómo podrían abordar el problema.
#
# 2. Análisis del EDA (Análisis Exploratorio de Datos)
#     - Se discutirán las observaciones y conclusiones obtenidas acerca de los datos proporcionados. A lo largo de su respuesta, debe responder preguntas como:
#         - ¿Como se comportan las variables numéricas? ¿y las categóricas?
#         - ¿Existen valores nulos en el dataset? ¿En qué columnas? ¿Cuantos?
#         - ¿Cuáles son las categorías y frecuencias de las variables categóricas?
#         - ¿Existen datos duplicados en el conjunto?
#         - ¿Existen relaciones o patrones visuales entre las variables?
#         - ¿Existen anomalías notables o preocupantes en los datos?
# 3. Creación de Clusters y Anomalías
#     - Se justificará la elección de los algoritmos a utilizar y sus hiperparámetros. En el caso de clustering, justifique además el número de clusters.
#
# 4. Análisis de Resultados
#     - Se examinarán los resultados obtenidos a partir de los clústers y anomalías generadas. ¿Se logra una separación efectiva de los datos? Entregue una interpretación de lo que representa cada clúster y anomalía.
# 5. Conclusión
#     - Se resumirán las principales conclusiones del análisis y se destacarán las implicaciones prácticas de los resultados obtenidos.

# %% [markdown]
# ### Introducción
#
# El análisis exploratorio de datos (EDA) corresponde a una etapa fundamental para cualquier proyecto de ciencia de datos, ya que permite comprender en profundidad la información que se puede extraer del conjunto de datos y así adquirir conocimientos valiosos. En el contexto del presente trabajo, se realizará un análisis exploratorio de los datos relacionados a las participaciones de los atletas olímpicos a lo largo de toda la historia de los Juegos Olímpicos. A través de este estudio, se pretende buscar revelar patrones, tendencias y relaciones dentro del conjunto de datos, brindando así una visión detallada de la evolución de los Juegos Olímpicos a través del paso del tiempo y de la diversidad de deportistas que han competido en ellos.
#
# El conjunto de datos proporciona una vasta información acerca de los competidores de los juegos. Las variables destacadas del dataset corresponden a información personal del competidor, tal como el nombre, el género, la nacionalidad, la edad, el peso y la altura, también información respectiva de los juegos, tal como el año del juego en que compitió, la temporada del año, la ciudad donde se realizó el evento, el deporte asociado a la competición, el nombre de la competición, y por último la información asociada al rendimiento del atleta en dicha competición (si recibió medalla o no).
#
# Este análisis exploratorio de datos se realizará gracias a un programa que permite realizar este tipo de análisis a cualquier conjunto de datos, que logra hacer un análisis profundo de las variables del dataset y de su comportamiento, además de aplicar algoritmos de clustering y de detección de anomalías para robustecer este estudio.

# %% [markdown]
# ### Análisis exploratorio de datos (EDA)
#
# A continuación, se procede a realizar el análisis exploratorio de los datos de los Juegos Olímpicos. En primera instancia, se analizará un cuadro de resumen que permite dar una noción del comportamiento de las variables, si son categóricas, numéricas, y en ese caso conocer su distribución.

# %%
test=Profiler(df)
test.summarize()
# Out:
# Número de Datos Duplicados: 668
# % de Datos Duplicados: 0.25%
#
#
# Variable: ID (Categorica)
# Número de Valores Únicos: 135571
# % de Valores Faltantes: 0.00%
# Valor Mínimo: 1
# Valor Máximo: 135571
# Promedio: 68248.95439590434
# Percentil 25: 34643.0
# Percentil 50 (Mediana): 68205.0
# Percentil 75: 102097.25
#
#
# Variable: Name (Categorica)
# Número de Valores Únicos: 134732
# % de Valores Faltantes: 0.00%
#
#
# Variable: Sex (Categorica)
# Número de Valores Únicos: 2
# % de Valores Faltantes: 0.00%
#
#
# Variable: Team (Categorica)
# Número de Valores Únicos: 1184
# % de Valores Faltantes: 0.00%
#
#
# Variable: NOC (Categorica)
# Número de Valores Únicos: 230
# % de Valores Faltantes: 0.00%
#
#
# Variable: Games (Categorica)
# Número de Valores Únicos: 51
# % de Valores Faltantes: 0.00%
#
#
# Variable: Year (Categorica)
# Número de Valores Únicos: 35
# % de Valores Faltantes: 0.00%
# Valor Mínimo: 1896
# Valor Máximo: 2016
# Promedio: 1978.3784800601957
# ...

# %% [markdown]
# A modo general, se puede ver que el dataset presenta una cantidad mínima de datos duplicados (0.25%). Con respecto a los valores nulos, se puede verificar que los únicos valores nulos presentes en el dataset corresponden a aquellos de la columna 'medalla', que intuitivamente representen que aquellos atletas no obtuvieron ninguna de las tres posibles preseas en su participación. Con respecto a esto, si bien es la única variable con valores nulos, 'Medal' contiene una cantidad considerable de valores nulos (85.33%), por lo que en las secciones posteriores la opción de eliminar esos registros puede tener un alto impacto en el análisis de este dataset. Por otra parte, se puede ver que hay una columna categórica que aparentemente no corresponde a una columna atómica, pues incluso en su nombre hace referencia a las tres columnas referentes a la información personal del atleta: 'age', 'height' y 'weight'. Esto claramente se debe corregir, puesto que quizás hayan anomalías en cada una de estas variables que se estarían ignorando sólo por el hecho de venir contenidas dentro de una sola columna.
#
# Para poder realizar el análisis exploratorio respectivo y profundo,es necesario realizar una pre limpieza de la data para separar aquellas columnas que no estén atomizadas.

# %%
df1=test.clean_data(drop_duplicates=False)
Profiler(df1).summarize()
# Out:
# La data limpia está en: EDA_10-11-2023\clean_data\data.csv
# Número de Datos Duplicados: 1385
# % de Datos Duplicados: 0.51%
#
#
# Variable: ID (Categorica)
# Número de Valores Únicos: 135571
# % de Valores Faltantes: 0.00%
# Valor Mínimo: 1
# Valor Máximo: 135571
# Promedio: 68248.95439590434
# Percentil 25: 34643.0
# Percentil 50 (Mediana): 68205.0
# Percentil 75: 102097.25
#
#
# Variable: Name (Categorica)
# Número de Valores Únicos: 134732
# % de Valores Faltantes: 0.00%
#
#
# Variable: Sex (Categorica)
# Número de Valores Únicos: 2
# % de Valores Faltantes: 0.00%
#
#
# Variable: Team (Categorica)
# Número de Valores Únicos: 1184
# % de Valores Faltantes: 0.00%
#
#
# Variable: NOC (Categorica)
# Número de Valores Únicos: 230
# % de Valores Faltantes: 0.00%
#
#
# Variable: Games (Categorica)
# Número de Valores Únicos: 51
# % de Valores Faltantes: 0.00%
#
#
# Variable: Year (Categorica)
# Número de Valores Únicos: 35
# % de Valores Faltantes: 0.00%
# Valor Mínimo: 1896
# ...

# %% [markdown]
# Luego de realizar la "desatomización" de las columnas, se observa un cambio en los resultados preeliminares del análisis. En cuanto a los datos duplicados, se ve que hay un aumento con respecto a la data cruda, donde el número de datos duplicados corresponde a 1385 (un 0.51% del total). Con respecto a los valores nulos, se ve que habían valores nulos escondidos en las variables "desatomizadas", donde en 'age' hay un 3.49% de valores nulos, pero tanto en 'height' como en 'weight' hay cantidades considerables de valores nulos (22.19% y 23.19%, respectivamente).
#
# Para robustecer el análisis de cada una de las variables por separado y en conjunto, a continuación se proporcionan unos gráficos tanto para las variables categóricas como numéricas, y finalmente una matriz de correlación para el análisis multivariado del dataset.

# %%
test.plot_vars(top_categories=10)
# Out:
# Los gráficos están guardados en: EDA_10-11-2023\plots

# %% [markdown]
# - Partiendo por la variable ***ID***, si bien aparece como una variable numérica, no es una variable que entrege información relevante del individuo más que el número que lo identificación del mismo.
# - Luego, se tiene la variable categórica ***Name***, que cumple una función similar a la de 'ID' pero en vez de ser númerica es categórica.
# - A continuación, se presenta la variable categórica ***Sex***, que entrega información acerca de que sexo es el atleta. Esta variable evidencia que en el dataset hay una predominancia de atletas masculinos por sobre las atletas femeninas, en donde la desproporción se ve de manera evidente en el gráfico (casi 200.000 hombres versus cerca de 75.000 mujeres).
# - Siguiendo con la variable categórica ***Team***, que refleja la dominancia de los paises universalmente conocidos como potencias en las nacionalidades de los competidores, en donde el primer lugar lo toma en solitario Estados Unidos, seguido por Francia, muy de cerca luego Reino Unido, Italia y Alemania, entre otros. La única sorpresa de este ranking es la ausencia de China, ya que siempre compite de manera muy reñida el podio con Estados Unidos, y ni siquiera aparece en el top 10.
# - La siguiente variable a estudiar es ***Games***, que corresponde a una variable categórica que representa a los Juegos Olímpicos en el cual compitió el atleta, en donde se puede ver que hay ciertos juegos que concentran la mayoría de los datos.
# - Otra variable que complementa el análisis de la anterior es ***Year***, donde se ve que el gráfico de densidad de la misma que los años más recientes tiene mayor cantidad de datos respecto al año, lo que señala que hay mayor participación en los juegos más recientes.
# - Luego, se presenta la variable categórica ***Season***, que corresponde a sólo dos valores: 'Summer' o 'Winter'. En el gráfico, se ve que hay mucha más información relacionada a los Juegos Olímpicos de verano.
# - A continuación, se tiene la variable ***City*** que indica en que ciudad se realizaron los Juegos Olímpicos. En base al gráfico del top 10 de categorías de la variable, se puede evidenciar que la ciudad que más se repite en el dataset es Londres, con más de 20.000 registros.
# - Siguiendo con la variable categórica ***Sport***, que refleja el deporte en el cual compitió el atleta. En base al gráfico de las categorías más repetidas, se ve que el deporte que contiene la mayor cantidad de registros es 'Athletics'. En base al conocimiento de los juegos, se puede decir que en el atletismo hay muchas más competencias que en los demás deportes, lo cual podría explicar este fenómeno de porque es el deporte que más se repite en los registros.
# - Otra variable interesante es la de ***Medal***, que indica si el atleta consiguió o no una medalla. También mencionar que esta variable es la que contiene la mayor cantidad de valores faltantes, por lo que es crucial para el análisis deterinar que es lo que se va a hacer con estos valores faltantes. Intuitivamente, si un atleta no tiene registro de medalla debe ser porque simplemente no consiguió una medalla en su participación, por lo que la mejor opción para no alterar drasticamente el análisis del dataset sería incluir una nueva categoría para almacenar estos valores (por ejemplo, categoría 'No medal').
# - Luego, se tienen las tres variables relacionadas a información y datos personales del atleta, como lo son ***age***, ***height*** y ***weight***. En el caso de *age*, se ve que la mayoría de la población se encuentra en un rango de entre 20 y 30 años aproximadamente, en *height* se ve que la mayoría se concentra en los 150 cm y los 200 cmm, y en el caso de *weight* la mayoría se concentra en el rango de 40 y 100 kg aproximadamente.
#
# Con respecto al estudio multivariado del dataset, en base al gráfico de la matriz de correlación de las variables numéricas, se puede ver que no hay grandes correlaciones entre las variables, lo cual es bueno porque evita el problema de trabajar las correlaciones entre las variables. Ahora, se ve una excepción que es el caso de las variables ***height*** y ***weight***, donde tienen una correlación de 0.8. Esta correlación no es ninguna sorpresa, puesto que se puede inferir que exista una correlación positiva entre estas dos variables, sobre todo en los atletas (salvo aquellos deportes que requieran de los atletas mayor masa).

# %% [markdown]
# ### Clustering y anomalías
#
# Se decidió utilizar `KMeans` ya que para encontrar la cantidad óptima de clusters se obtiene utilizando el método del codo. Este método en general es util solo para `KMeans` por lo que preferimos no utilizar otro algoritmo de Clusterización. Se utilizó en su configuración estándar a excepción de la cantidad de clusters, el cuál para los datos actuales recomendó 6 clusters. Para el algoritmo de detección de anomalías se decidió utilizar `IsolationForest` en su configuración estándar debido a sus buenos resultados en problemas similares. Como se puede ver de los gráficos anteriores se lográ una buena separación de los clusters al verlos utilizando PCA, a excepción del cluster 1, 2 y 3. Estos se mantienen bastante unidos y estan solapados.

# %%
test=Profiler(df)
#df.head()
#test.data.head()
test.profile()
# Out:
# Número de Datos Duplicados: 668
# % de Datos Duplicados: 0.25%
#
#
# Variable: ID (Categorica)
# Número de Valores Únicos: 135571
# % de Valores Faltantes: 0.00%
# Valor Mínimo: 1
# Valor Máximo: 135571
# Promedio: 68248.95439590434
# Percentil 25: 34643.0
# Percentil 50 (Mediana): 68205.0
# Percentil 75: 102097.25
#
#
# Variable: Name (Categorica)
# Número de Valores Únicos: 134732
# % de Valores Faltantes: 0.00%
#
#
# Variable: Sex (Categorica)
# Número de Valores Únicos: 2
# % de Valores Faltantes: 0.00%
#
#
# Variable: Team (Categorica)
# Número de Valores Únicos: 1184
# % de Valores Faltantes: 0.00%
#
#
# Variable: NOC (Categorica)
# Número de Valores Únicos: 230
# % de Valores Faltantes: 0.00%
#
#
# Variable: Games (Categorica)
# Número de Valores Únicos: 51
# % de Valores Faltantes: 0.00%
#
#
# Variable: Year (Categorica)
# Número de Valores Únicos: 35
# % de Valores Faltantes: 0.00%
# Valor Mínimo: 1896
# Valor Máximo: 2016
# Promedio: 1978.3784800601957
# ...

# %% [markdown]
# ### Análisis de resultados
#
# Se puede ver que la principal diferencia entre los cluster es el año de la competición. El cluster 0 caracteriza a los años 1996, 1988, 1992. El cluster 1 caracteriza los años 2000, 2012, 1992. El cluster 2 caracteriza los años 1984, 2004, 1992. El cluster 4 caracteriza los años 2008, 2012, 2000 y el cluster 5 los años 1984, 2004 y 1992. Con respecto a los otuliers, el `Isolation Forest` no encontró outliers en los datos.

# %% [markdown]
# ### Conclusiones
#
#
#
# Una de las conclusiones es que al momento de hacer OneHot Encoding, las variables con un rango mayor toman mayor importancia. En particular por que al tener mayor variabilidad en los datos las otras columnas numericas tienen mayor importancia cuando se ahce clustering.
